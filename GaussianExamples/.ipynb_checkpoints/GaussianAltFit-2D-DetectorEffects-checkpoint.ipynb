# %%
# standard library imports
from __future__ import absolute_import, division, print_function

import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras import Sequential
from keras.layers import Lambda, Dense, Input, Layer, Dropout
from keras.models import Model
from keras.utils import to_categorical
from keras.callbacks import LambdaCallback, EarlyStopping
import keras.backend as K
import keras


import inspect
# Out:
# Using TensorFlow backend.

# %%
#Check Versions
print(tf.__version__) #1.15.0
print(keras.__version__) #2.2.4
# Out:
# 1.15.0
# 2.2.4

# %% [markdown]
# # Alternative DCTR fitting algorithm
#
# The DCTR paper (https://arxiv.org/abs/1907.08209) shows how a continuously parameterized NN used for reweighting:
#
# $f(x,\theta)=\text{argmax}_{f'}(\sum_{i\in\bf{\theta}_0}\log f'(x_i,\theta)+\sum_{i\in\bf{\theta}}\log (1-f'(x_i,\theta)))$
#
# can also be used for fitting:
#
# $\theta^*=\text{argmax}_{\theta'}(\sum_{i\in\bf{\theta}_0}\log f(x_i,\theta')+\sum_{i\in\bf{\theta}}\log (1-f(x_i,\theta')))$
#
# This works well when the reweighting and fitting happen on the same 'level'.  However, if the reweighting happens at truth level (before detector simulation) while the fit happens in data (after the effects of the detector), this procedure will not work.  It works only if the reweighting and fitting both happen at detector-level or both happen at truth-level.  This notebook illustrates an alternative procedure:
#
# $\theta^*=\text{argmax}_{\theta'}\text{min}_{g}(-\sum_{i\in\bf{\theta}_0}\log g(x_i)-\sum_{i\in\bf{\theta}}(f(x_i,\theta')/(1-f(x_i,\theta')))\log (1-g(x_i)))$
#
# where the $f(x,\theta')/(1-f(x,\theta'))$ is the reweighting function.  The intuition of the above equation is that the classifier $g$ is trying to distinguish the two samples and we try to find a $\theta$ that makes $g$'s task maximally hard.  If $g$ can't tell apart the two samples, then the reweighting has worked!  This is similar to the minimax graining of a GAN, only now the analog of the generator network is the reweighting network which is fixed and thus the only trainable parameters are the $\theta'$.  The advantage of this second approach is that it readily generalizes to the case where the reweighting happens on a different level:
#
# $\theta^*=\text{argmax}_{\theta'}\text{min}_{g}(-\sum_{i\in\bf{\theta}_0}\log g(x_{D,i})-\sum_{i\in\bf{\theta}}\frac{f(x_{T,i},\theta')}{(1-f(x_{T,i},\theta'))}\log (1-g(x_{D,i})))$
#
# where $x_T$ is the truth value and $x_D$ is the detector-level value.  In simulation (the second sum), these come in pairs and so one can apply the reweighting on one level and the classification on the other.  Asympotitically, both this method and the one in the body of the DCTR paper learn the same result: $\theta^*=\theta_0$.

# %% [markdown]
# # Training a DCTR Model
# First, we need to train a DCTR model to provide us with a reweighting function to be used during fitting.
# This is taken directly from the first Gaussian Notebook.

# %% [markdown]
# We will now parametrize our network by giving it $\mu$ and $\sigma$ values in addition to $X_i\sim\mathcal{N}(\mu, \sigma)$.
#
# First we uniformly sample $\mu$ and $\sigma$ values in some range

# %%
n_data_points = 10**6
mu_min = -2
mu_max = 2
mu_values = np.random.uniform(mu_min, mu_max, n_data_points)

sigma_min = 1/3
sigma_max = 3
sigma_values = np.random.uniform(sigma_min, sigma_max, n_data_points)

# %% [markdown]
# We then sample from normal distributions with these $\mu$ and $\sigma$ values.

# %%
X0 = [(np.random.normal(0, 1), mu_values[i], sigma_values[i]) for i in range(n_data_points)] # Note the zero in normal(0, 1) 
X1 = [(np.random.normal(mu_values[i], sigma_values[i]), mu_values[i], sigma_values[i]) for i in range(n_data_points)]

# %% [markdown]
# Please note that the samples in X0 are not paired with $\mu=0, \sigma = 1$ as this would make the task trivial.
#
# Instead it is paired with the $\mu, \sigma$ values uniformly sampled in the specified range [$\mu_{min}, \mu_{max}$] and [$\sigma_{min}, \sigma_{max}$].
#
# For every value of $\mu$ in mu_values and every value of $\sigma$ in sigma_values, the network sees one event drawn from $\mathcal{N}(0,1)$ and $\mathcal{N}(\mu,\sigma)$, and it learns to classify them.
#
# I.e. we have one network that's parametrized by $\mu$ and $\sigma$ that classifies between events from $\mathcal{N}(0,1)$ and $\mathcal{N}(\mu,\sigma)$, and a trained network will give us the likelihood ratio to reweight from one to another.

# %%
Y0 = to_categorical(np.zeros(n_data_points), num_classes=2)
Y1 = to_categorical(np.ones(n_data_points), num_classes=2)

X = np.concatenate((X0, X1))
Y = np.concatenate((Y0, Y1))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ## Build Model

# %%
inputs = Input((3,))
hidden_layer_1 = Dense(128, activation='relu')(inputs)
hidden_layer_2 = Dense(128, activation='relu')(hidden_layer_1)
hidden_layer_3 = Dense(128, activation='relu')(hidden_layer_2)
outputs = Dense(2, activation='softmax')(hidden_layer_3)

dctr_model = Model(inputs = inputs, outputs = outputs)
dctr_model.compile(loss='categorical_crossentropy', optimizer='Adam')
# Out:
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## Train DCTR model

# %%
earlystopping = EarlyStopping(patience = 10,
                              restore_best_weights=True)
dctr_model.fit(X_train, Y_train, 
          epochs=200, 
          batch_size = 10000,
          validation_data = (X_test, Y_test),
          callbacks = [earlystopping])
# Out:
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1600000 samples, validate on 400000 samples
# Epoch 1/200
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/asuresh/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1600000/1600000 [==============================] - 4s 2us/step - loss: 0.5538 - val_loss: 0.5372
# Epoch 2/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5345 - val_loss: 0.5334
# Epoch 3/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5336 - val_loss: 0.5331
# Epoch 4/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5334 - val_loss: 0.5323
# Epoch 5/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5333 - val_loss: 0.5322
# Epoch 6/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5330 - val_loss: 0.5324
# Epoch 7/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5331 - val_loss: 0.5324
# Epoch 8/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5331 - val_loss: 0.5325
# Epoch 9/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5332 - val_loss: 0.5324
# Epoch 10/200
# 1600000/1600000 [==============================] - 4s 2us/step - loss: 0.5330 - val_loss: 0.5324
# Epoch 11/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5330 - val_loss: 0.5326
# Epoch 12/200
# 1600000/1600000 [==============================] - 3s 2us/step - loss: 0.5329 - val_loss: 0.5321
# Epoch 13/200
# 1600000/1600000 [==============================] - 4s 2us/step - loss: 0.5330 - val_loss: 0.5321
# Epoch 14/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5330 - val_loss: 0.5322
# Epoch 15/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5330 - val_loss: 0.5322
# Epoch 16/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5330 - val_loss: 0.5324
# Epoch 17/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5330 - val_loss: 0.5321
# Epoch 18/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5322
# Epoch 19/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5320
# Epoch 20/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5324
# Epoch 21/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5330 - val_loss: 0.5325
# Epoch 22/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5321
# Epoch 23/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5320
# Epoch 24/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5320
# Epoch 25/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5321
# Epoch 26/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5320
# Epoch 27/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5320
# Epoch 28/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5320
# Epoch 29/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5320
# Epoch 30/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5320
# Epoch 31/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5324
# Epoch 32/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5328 - val_loss: 0.5320
# Epoch 33/200
# 1600000/1600000 [==============================] - 4s 3us/step - loss: 0.5329 - val_loss: 0.5320

# %% [markdown]
# ## Validate DCTR for any $\mu$ and $\sigma$

# %%
mu1 = 1
sigma1 = 1.5
assert mu1>=mu_min and mu1<=mu_max # choose mu1 in valid range
assert sigma1>=sigma_min and sigma1<=sigma_max # choose mu1 in valid range
X0_val = np.random.normal(0, 1, n_data_points)
X1_val = np.random.normal(mu1, sigma1, n_data_points)

# %%
X_input = np.array([(x, mu1, sigma1) for x in X0_val])

# %%
preds = dctr_model.predict(X_input)
weights = preds[:,1]/preds[:,0]

# %%
bins = np.linspace(-6,5,31)
plt.hist(X0_val, bins = bins, alpha = 0.5, label = r'$\mu=0$, $\sigma=1$')
plt.hist(X0_val, bins = bins, label = r'$\mu=0$, $\sigma=1$ wgt.', weights=weights, histtype='step', color='k')
plt.hist(X1_val, bins = bins, alpha = 0.5, label = r'$\mu={}$, $\sigma={}$'.format(mu1, sigma1))
plt.legend()
plt.show()

# %% [markdown]
# # Saving Model

# %%
'''
model_json = dctr_model.to_json()
with open("2d_gaussian_dctr_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
dctr_model.save_weights("2d_gaussian_dctr_model.h5")
print("Saved model to disk")
'''
# Out:
# '\nmodel_json = dctr_model.to_json()\nwith open("2d_gaussian_dctr_model.json", "w") as json_file:\n    json_file.write(model_json)\n# serialize weights to HDF5\ndctr_model.save_weights("2d_gaussian_dctr_model.h5")\nprint("Saved model to disk")\n'

# %% [markdown]
# # Alternative Fit

# %% [markdown]
# # Setup the dataset
#
# We'll show the new setup with a simple Gaussian example.  Let's start by setting up the dataset.

# %% [markdown]
# To apply detector effects, each event $x_{T,i}$in the sample is smeared by shifting by $Z_{i}$ from $Z = \mathcal{N}(0,\epsilon)$,where $\epsilon$ represents the smearing. Thus: $x_{D,i} = x_{T,i} + Z_{i}$

# %%
N = 10**6
#param = (mu, sigma)
theta0_param = (0,1) #this is the simulation ... N.B. this notation is reversed from above!
theta1_param = (1,1.5) #this is the data (the target)

epsilon =theta0_param[1]/2 #Smearing width

theta0_T = np.random.normal(theta0_param[0],theta0_param[1],N)
theta0_D = np.array([(x + np.random.normal(0, epsilon)) for x in theta0_T]) #Detector smearing
theta0 = np.stack([theta0_T, theta0_D], axis = 1)

theta1_T = np.random.normal(theta1_param[0],theta1_param[1],N)
theta1_D = np.array([(x + np.random.normal(0, epsilon)) for x in theta1_T]) #Detector smearing
theta1 = np.stack([theta1_T, theta0_D], axis = 1)

# %%
bins = np.linspace(-6,6,31)

plt.figure()
plt.title("2D Gaussian: Simulation\n($\mu$ = {:.2f}, $\sigma$ = {:.2f}) w detector effects".format(theta0_param[0], theta0_param[1]))
plt.hist(theta0_T, bins = bins, alpha = 0.5, label = 'Truth')
plt.hist(theta0_D, bins = bins, alpha = 0.5, label = 'Detector')
plt.legend()
#plt.savefig("2D Gaussian: Simulation ($\mu$ = {:.2f}, $\sigma$ = {:.2f}) w detector effects.png".format(theta0_param[0], theta0_param[1]))
plt.show()

plt.figure()
plt.title("2D Gaussian: Data\n($\mu$ = {:.2f}, $\sigma$ = {:.2f}) w detector effects".format(theta1_param[0], theta1_param[1]))
plt.hist(theta1_T, bins = bins, alpha = 0.5, label = 'Truth')
plt.hist(theta1_D, bins = bins, alpha = 0.5, label = 'Detector')
plt.legend()
#plt.savefig("2D Gaussian: Data ($\mu$ = {:.2f}, $\sigma$ = {:.2f}) w detector effects.png".format(theta1_param[0], theta1_param[1]))
plt.show()

# %%
#'Erasing' Truth level for data, we can't actually observe this
theta1 = np.stack([np.zeros_like(theta0_D), theta0_D], axis = 1)

# %%
labels0 = np.zeros(len(theta0))
labels1 = np.ones(len(theta1))

xvals = np.concatenate([theta0_D,theta1_D])
y_true = np.concatenate([labels0,labels1]) 
# 'hiding' truth level for simulation in model output (used in reweighting)
truth_level = np.concatenate([theta0_T, theta1_T])
yvals = np.stack([y_true, truth_level], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(xvals, yvals, test_size=0.5)

# %% [markdown]
# # Fitting Model
#
# We'll start by showing that for fixed $\theta$, the maximum loss occurs when $\theta=\theta_1$.

# %% [markdown]
# # Loading Model

# %%
# load json and create model
'''
json_file = open('2d_gaussian_dctr_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
dctr_model = keras.models.model_from_json(loaded_model_json)
# load weights into new model
dctr_model.load_weights("2d_gaussian_dctr_model.h5")
print("Loaded model from disk")
'''
# Out:
# '\njson_file = open(\'2d_gaussian_dctr_model.json\', \'r\')\nloaded_model_json = json_file.read()\njson_file.close()\ndctr_model = keras.models.model_from_json(loaded_model_json)\n# load weights into new model\ndctr_model.load_weights("2d_gaussian_dctr_model.h5")\nprint("Loaded model from disk")\n'

# %% [markdown]
# # Defining reweighting functions
#
# $w(x_{T,i},\theta)=((f(x_{T,i},\theta)/(1-f(x_{T,i},\theta)))$
#
# Takes observable from simulation ${\bf \theta_0}$ and weights it to observable from data (target) ${\bf \theta_1}$.

# %%
def reweight(d): #from NN (DCTR)
    f = dctr_model(d)
    weights = (f[:,1])/(f[:,0])
    weights = K.expand_dims(weights, axis = 1)
    return weights

# from analytical formula for normal distributions
def analytical_reweight(events, mu1, sigma1, mu0 = theta0_param[0], sigma0 = theta0_param[1]): 
    weights = (sigma0/sigma1)*K.exp(-0.5*(((events-mu1)/sigma1)**2-((events-mu0)/sigma0)**2))
    #weights = K.expand_dims(weights, axis = 1)
    return weights

# %% [markdown]
# # Cross Section for $\mu$

# %%
myinputs = Input(shape=(1,), dtype = tf.float32)
x = Dense(128, activation='relu')(myinputs)
x2 = Dense(128, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x2)
          
model = Model(inputs=myinputs, outputs=predictions)
model.summary()
batch_size = 500

def my_loss_wrapper(val=0):
    
    def my_loss(y_true,y_pred):
        y_true = tf.gather(y_true, np.arange(batch_size)) 
        y_labels = tf.gather(y_true, [0], axis = 1) #actual y_true for loss
        x_T = tf.gather(y_true, [1], axis = 1) # sim truth for reweighting

        theta_prime = [val, theta1_param[1]] #fixed theta_sigma = sigma_truth
    
        #creating tensor with same length as inputs, with theta_prime in every entry
        concat_input_and_params = K.ones(shape = (x_T.shape[0], 2))*theta_prime
        #combining and reshaping into correct format:
        data = K.concatenate((x_T, concat_input_and_params), axis=-1)
        
        #w = reweight(data) # NN reweight
        
        # analytical reweight
        
        w = analytical_reweight(events = x_T, 
                                mu1 = theta_prime[0], 
                                sigma1 = theta_prime[1]) 
        
        # Mean Squared Loss
        t_loss = y_labels*(y_labels - y_pred)**2+(w)*(1.-y_labels)*(y_labels - y_pred)**2
        # Categorical Cross-Entropy Loss
        '''
        #Clip the prediction value to prevent NaN's and Inf's
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        
        t_loss = -((y_labels)*K.log(y_pred) +w*(1-y_labels)*K.log(1-y_labels))
        '''
        return K.mean(t_loss)
    return my_loss
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               256
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
thetas = np.linspace(-2,2,17)
lvals = []


for theta in thetas:
    print("testing theta = :", theta)
    model.compile(optimizer='adam', loss=my_loss_wrapper(theta),metrics=['accuracy'])
    model.fit(np.array(X_train), y_train, epochs=1, batch_size=500,validation_data=(np.array(X_test), y_test),verbose=1)
    lvals+=[model.history.history['val_loss']]
    print
    pass
print(lvals)
# Out:
# testing theta = : -2.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.1212 - acc: 0.2888 - val_loss: 0.1207 - val_acc: 0.2893
# testing theta = : -1.75
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.1340 - acc: 0.2940 - val_loss: 0.1339 - val_acc: 0.2917
# testing theta = : -1.5
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.1477 - acc: 0.2995 - val_loss: 0.1478 - val_acc: 0.2980
# testing theta = : -1.25
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.1617 - acc: 0.3046 - val_loss: 0.1618 - val_acc: 0.3043
# testing theta = : -1.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.1758 - acc: 0.3085 - val_loss: 0.1759 - val_acc: 0.3090
# testing theta = : -0.75
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.1897 - acc: 0.3133 - val_loss: 0.1899 - val_acc: 0.3126
# testing theta = : -0.5
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2031 - acc: 0.3180 - val_loss: 0.2034 - val_acc: 0.3175
# testing theta = : -0.25
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2155 - acc: 0.3218 - val_loss: 0.2160 - val_acc: 0.3213
# testing theta = : 0.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2266 - acc: 0.3248 - val_loss: 0.2273 - val_acc: 0.3231
# testing theta = : 0.25
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2358 - acc: 0.3268 - val_loss: 0.2375 - val_acc: 0.3286
# testing theta = : 0.5
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2429 - acc: 0.3282 - val_loss: 0.2438 - val_acc: 0.3284
# testing theta = : 0.75
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2472 - acc: 0.3276 - val_loss: 0.2481 - val_acc: 0.3282
# testing theta = : 1.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2485 - acc: 0.2801 - val_loss: 0.2506 - val_acc: 0.2498
# testing theta = : 1.25
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2474 - acc: 0.1926 - val_loss: 0.2485 - val_acc: 0.1884
# testing theta = : 1.5
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2421 - acc: 0.1782 - val_loss: 0.2432 - val_acc: 0.1731
# testing theta = : 1.75
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2358 - acc: 0.1780 - val_loss: 0.2364 - val_acc: 0.1717
# testing theta = : 2.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2270 - acc: 0.1811 - val_loss: 0.2264 - val_acc: 0.1755
# [[0.12070256697759033], [0.13388051200285553], [0.14782801641523838], [0.16178126465529202], [0.1758906429708004], [0.18988676589727402], [0.20337252189964056], [0.2160015453249216], [0.22726254322379827], [0.2374808572754264], [0.2438280276656151], [0.2481097273826599], [0.2505581434890628], [0.24849428709596397], [0.24318454153835772], [0.23642855301499366], [0.2264191409572959]]

# %%
plt.plot(thetas,lvals)
plt.title("$\mu$ Cross Section\nFixed $\sigma = \sigma_{Truth}$")
plt.xlabel(r'$\theta_{\mu}$')
plt.ylabel('Loss')
plt.vlines(theta1_param[0], ymin = np.min(lvals), ymax = np.max(lvals), label = 'Truth')
plt.legend()
#plt.savefig("GaussianAltFit-2D-DetectorEffects-\mu cross section.png")
plt.show()

# %% [markdown]
# # Cross Section for $\sigma$

# %%
myinputs = Input(shape=(1,), dtype = tf.float32)
x = Dense(128, activation='relu')(myinputs)
x2 = Dense(128, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x2)
          
model = Model(inputs=myinputs, outputs=predictions)
model.summary()


def my_loss_wrapper(val=0):
    
    def my_loss(y_true,y_pred):
        y_true = tf.gather(y_true, np.arange(batch_size)) 
        y_labels = tf.gather(y_true, [0], axis = 1) #actual y_true for loss
        x_T = tf.gather(y_true, [1], axis = 1) # sim truth for reweighting

        theta_prime = [theta1_param[0], val] #fixed theta_mu = mu_truth
    
        #creating tensor with same length as inputs, with theta_prime in every entry
        concat_input_and_params = K.ones(shape = (x_T.shape[0], 2))*theta_prime
        #combining and reshaping into correct format:
        data = K.concatenate((x_T, concat_input_and_params), axis=-1)
        
        #w = reweight(data) # NN reweight
        
        # functional analytical reweight
        # analytical reweight
        
        w = analytical_reweight(events = x_T, 
                                mu1 = theta_prime[0], 
                                sigma1 = theta_prime[1]) 
        
        # Mean Squared Loss
        t_loss = y_labels*(y_labels - y_pred)**2+(w)*(1.-y_labels)*(y_labels - y_pred)**2
        
        # Categorical Cross-Entropy Loss
        '''
        #Clip the prediction value to prevent NaN's and Inf's
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        
        t_loss = -((y_true)*K.log(y_pred) +w*(1-y_true)*K.log(1-y_pred))
        '''
        return K.mean(t_loss)
    return my_loss
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               256
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
thetas = np.linspace(0.5,2,16)
lvals = []


for theta in thetas:
    print("testing theta = :", theta)
    model.compile(optimizer='adam', loss=my_loss_wrapper(theta),metrics=['accuracy'])
    model.fit(np.array(X_train), y_train, epochs=1, batch_size=500,validation_data=(np.array(X_test), y_test),verbose=1)
    lvals+=[model.history.history['val_loss']]
    print
    pass
print(lvals)
# Out:
# testing theta = : 0.5
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2013 - acc: 0.2490 - val_loss: 0.1999 - val_acc: 0.2476
# testing theta = : 0.6
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2093 - acc: 0.2479 - val_loss: 0.2088 - val_acc: 0.2497
# testing theta = : 0.7
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2176 - acc: 0.2487 - val_loss: 0.2173 - val_acc: 0.2488
# testing theta = : 0.8
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2251 - acc: 0.2493 - val_loss: 0.2251 - val_acc: 0.2488
# testing theta = : 0.9
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2317 - acc: 0.2500 - val_loss: 0.2326 - val_acc: 0.2552
# testing theta = : 1.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2372 - acc: 0.2494 - val_loss: 0.2376 - val_acc: 0.2517
# testing theta = : 1.1
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2417 - acc: 0.2511 - val_loss: 0.2423 - val_acc: 0.2490
# testing theta = : 1.2000000000000002
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2451 - acc: 0.2513 - val_loss: 0.2457 - val_acc: 0.2493
# testing theta = : 1.3
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2472 - acc: 0.2490 - val_loss: 0.2480 - val_acc: 0.2482
# testing theta = : 1.4
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2484 - acc: 0.2396 - val_loss: 0.2493 - val_acc: 0.2418
# testing theta = : 1.5
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2484 - acc: 0.2546 - val_loss: 0.2497 - val_acc: 0.3147
# testing theta = : 1.6
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2484 - acc: 0.2690 - val_loss: 0.2493 - val_acc: 0.2641
# testing theta = : 1.7000000000000002
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2469 - acc: 0.2803 - val_loss: 0.2477 - val_acc: 0.2763
# testing theta = : 1.8
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2448 - acc: 0.2734 - val_loss: 0.2459 - val_acc: 0.2548
# testing theta = : 1.9000000000000001
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2440 - acc: 0.2621 - val_loss: 0.2439 - val_acc: 0.2235
# testing theta = : 2.0
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2412 - acc: 0.2538 - val_loss: 0.2414 - val_acc: 0.2457
# [[0.19989923698455095], [0.20883211413770914], [0.21729265132546424], [0.22508394488692285], [0.23257749842852354], [0.2376256610006094], [0.2422964374050498], [0.24572002489864825], [0.24804924489557742], [0.24925324821472167], [0.24967865953594445], [0.2492926511913538], [0.24765421171486376], [0.24594338458031417], [0.24388764572888613], [0.24142552042752505]]

# %%
plt.plot(thetas,lvals)
plt.title("$\sigma$ Cross Section\nFixed $\mu = \mu{Truth}$")
plt.xlabel(r'$\theta_{\sigma}$')
plt.ylabel('Loss')
plt.vlines(theta1_param[1], ymin = np.min(lvals), ymax = np.max(lvals), label = 'Truth')
plt.legend()
#plt.savefig("GaussianAltFit-2D-DetectorEffects-\sigma cross section.png")
plt.show()

# %% [markdown]
# # Creating Model

# %% [markdown]
# Now, let's do the $\theta$ and $g$ optimization together with a minimax setup.

# %% [markdown]
# # Building and Training Fitting Model

# %%
print_weights = LambdaCallback(on_epoch_end=lambda batch,
                               logs: print(". theta fit = ",model_fit.layers[-1].get_weights()[-1]))
theta_fit_init = [0, 1]
fit_vals = [theta_fit_init]
append_fit_value = LambdaCallback(on_epoch_end=lambda batch, logs: 
                                               fit_vals.append(model_fit.layers[-1].get_weights()[0]))

callbacks = [print_weights, append_fit_value]

# %%
myinputs_fit = Input(shape=(1,))
x_fit = Dense(128, activation='relu')(myinputs_fit)
x2_fit = Dense(128, activation='relu')(x_fit)
predictions_fit = Dense(1, activation='sigmoid')(x2_fit)
identity = Lambda(lambda x: x + 0)(predictions_fit)

model_fit = Model(inputs=myinputs_fit, outputs=identity)
model_fit.layers[np.size(model_fit.layers)-1].add_weight(name="thetaX",shape=(2,),
                                                         initializer = keras.initializers.Constant(value = theta_fit_init),
                                                         trainable=True)
model_fit.summary()

train_theta = False

batch_size = 1000
lr = 5e-5 #smaller learning rate yields better precision
epochs = 75 #but requires more epochs to train
optimizer = keras.optimizers.Adam(lr=lr)

def my_loss_wrapper_fit(mysign = 1):
    theta = 0. #starting value
    #Getting theta_prime:
    if train_theta == False:
        theta_prime = model_fit.layers[-1].get_weights()[0] #when not training theta, fetch as np array 
    else:
        theta_prime = model_fit.trainable_weights[-1] #when trainingn theta, fetch as tf.Variable
    
    def my_loss(y_true,y_pred):
        y_true = tf.gather(y_true, np.arange(batch_size)) 
        y_labels = tf.gather(y_true, [0], axis = 1) #actual y_true for loss
        x_T = tf.gather(y_true, [1], axis = 1) # sim truth for reweighting
        
        #creating tensor with same length as inputs, with theta_prime in every entry
        concat_input_and_params = K.ones(shape = (x_T.shape[0], 2), dtype=tf.float32)*theta_prime
        data = K.concatenate((x_T, concat_input_and_params), axis=-1)
        
        #w = reweight(data) #NN reweight
        
        # analytical reweight
        
        w = analytical_reweight(events = x_T, 
                                mu1 = theta_prime[0], 
                                sigma1 = theta_prime[1]) 
        
        # Mean Squared Loss
        t_loss = mysign*(y_labels*(y_labels - y_pred)**2+(w)*(1.-y_labels)*(y_labels - y_pred)**2)
        # Categorical Cross-Entropy Loss
        
        #Clip the prediction value to prevent NaN's and Inf's
        """epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        
        t_loss = -mysign*((y_true)*K.log(y_pred) +w*(1-y_true)*K.log(1-y_pred))"""
        
        return K.mean(t_loss)
    return my_loss
    
for k in range(epochs):    
    print("Epoch: ",k )
    for i in range(len(model_fit.layers)-1):
        train_theta = False
        model_fit.layers[i].trainable = True
        pass
    
    train_theta = False
    model_fit.layers[-1].trainable = False
    #model.summary()    
    
    model_fit.compile(optimizer=optimizer, loss=my_loss_wrapper_fit(1),metrics=['accuracy'])
    print("Training g")
    model_fit.fit(np.array(X_train), y_train, epochs=1, batch_size=batch_size,validation_data=(np.array(X_test), y_test),verbose=1,callbacks=callbacks)

    #Now, fix g and train \theta.

    for i in range(len(model_fit.layers)-1):
        model_fit.layers[i].trainable = False
        pass    
    train_theta = True
    model_fit.layers[-1].trainable = True
    model_fit.compile(optimizer=optimizer, loss=my_loss_wrapper_fit(-1),metrics=['accuracy'])
    #model.summary()
    print("Training theta")
    model_fit.fit(np.array(X_train), y_train, epochs=1, batch_size=batch_size,validation_data=(np.array(X_test), y_test),verbose=1,callbacks=callbacks)    
    pass
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               256
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 129
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 1)                 2
# =================================================================
# Total params: 16,899
# Trainable params: 16,899
# Non-trainable params: 0
# _________________________________________________________________
# Epoch:  0
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2191 - acc: 0.3222 - val_loss: 0.2136 - val_acc: 0.3286
# . theta fit =  [0. 1.]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2179 - acc: 0.3287 - val_loss: -0.2212 - val_acc: 0.3286
# . theta fit =  [0.08561902 1.0812757 ]
# Epoch:  1
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2205 - acc: 0.3288 - val_loss: 0.2206 - val_acc: 0.3286
# . theta fit =  [0.08561902 1.0812757 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2252 - acc: 0.3288 - val_loss: -0.2287 - val_acc: 0.3286
# . theta fit =  [0.18160231 1.1668447 ]
# Epoch:  2
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2274 - acc: 0.3286 - val_loss: 0.2277 - val_acc: 0.3285
# . theta fit =  [0.18160231 1.1668447 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2311 - acc: 0.3287 - val_loss: -0.2341 - val_acc: 0.3285
# . theta fit =  [0.27538103 1.2350625 ]
# Epoch:  3
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2329 - acc: 0.3284 - val_loss: 0.2333 - val_acc: 0.3282
# . theta fit =  [0.27538103 1.2350625 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2359 - acc: 0.3284 - val_loss: -0.2384 - val_acc: 0.3282
# . theta fit =  [0.36746144 1.2949443 ]
# Epoch:  4
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2373 - acc: 0.3280 - val_loss: 0.2379 - val_acc: 0.3280
# . theta fit =  [0.36746144 1.2949443 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2392 - acc: 0.3282 - val_loss: -0.2413 - val_acc: 0.3280
# . theta fit =  [0.44970858 1.3283389 ]
# Epoch:  5
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2403 - acc: 0.3278 - val_loss: 0.2410 - val_acc: 0.3283
# . theta fit =  [0.44970858 1.3283389 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2419 - acc: 0.3285 - val_loss: -0.2439 - val_acc: 0.3283
# . theta fit =  [0.53012407 1.3567861 ]
# Epoch:  6
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2427 - acc: 0.3274 - val_loss: 0.2435 - val_acc: 0.3276
# . theta fit =  [0.53012407 1.3567861 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2438 - acc: 0.3278 - val_loss: -0.2456 - val_acc: 0.3276
# . theta fit =  [0.59694725 1.3776227 ]
# Epoch:  7
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: 0.2443 - acc: 0.3268 - val_loss: 0.2455 - val_acc: 0.3283
# . theta fit =  [0.59694725 1.3776227 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2454 - acc: 0.3284 - val_loss: -0.2472 - val_acc: 0.3283
# . theta fit =  [0.65709007 1.3955836 ]
# Epoch:  8
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2456 - acc: 0.3260 - val_loss: 0.2465 - val_acc: 0.3266
# . theta fit =  [0.65709007 1.3955836 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 7s 7us/step - loss: -0.2460 - acc: 0.3269 - val_loss: -0.2475 - val_acc: 0.3266
# . theta fit =  [0.7094284 1.4043521]
# Epoch:  9
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2464 - acc: 0.3244 - val_loss: 0.2474 - val_acc: 0.3267
# . theta fit =  [0.7094284 1.4043521]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: -0.2467 - acc: 0.3270 - val_loss: -0.2481 - val_acc: 0.3267
# . theta fit =  [0.745885  1.4121169]
# Epoch:  10
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2469 - acc: 0.3238 - val_loss: 0.2479 - val_acc: 0.3176
# . theta fit =  [0.745885  1.4121169]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: -0.2471 - acc: 0.3174 - val_loss: -0.2483 - val_acc: 0.3176
# . theta fit =  [0.77745116 1.4178752 ]
# Epoch:  11
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2473 - acc: 0.3229 - val_loss: 0.2486 - val_acc: 0.3270
# . theta fit =  [0.77745116 1.4178752 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: -0.2477 - acc: 0.3273 - val_loss: -0.2492 - val_acc: 0.3270
# . theta fit =  [0.8131919 1.4259344]
# Epoch:  12
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2476 - acc: 0.3184 - val_loss: 0.2487 - val_acc: 0.3277
# . theta fit =  [0.8131919 1.4259344]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: -0.2477 - acc: 0.3280 - val_loss: -0.2489 - val_acc: 0.3277
# . theta fit =  [0.83795124 1.4258468 ]
# Epoch:  13
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2479 - acc: 0.3170 - val_loss: 0.2492 - val_acc: 0.2908
# . theta fit =  [0.83795124 1.4258468 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: -0.2483 - acc: 0.2904 - val_loss: -0.2491 - val_acc: 0.2908
# . theta fit =  [0.8414164 1.4160787]
# Epoch:  14
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2479 - acc: 0.3182 - val_loss: 0.2490 - val_acc: 0.3253
# . theta fit =  [0.8414164 1.4160787]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 8s 8us/step - loss: -0.2479 - acc: 0.3256 - val_loss: -0.2492 - val_acc: 0.3253
# . theta fit =  [0.86557466 1.4159944 ]
# Epoch:  15
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: 0.2481 - acc: 0.3144 - val_loss: 0.2490 - val_acc: 0.3192
# . theta fit =  [0.86557466 1.4159944 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: -0.2479 - acc: 0.3190 - val_loss: -0.2492 - val_acc: 0.3192
# . theta fit =  [0.8839921 1.418152 ]
# Epoch:  16
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: 0.2481 - acc: 0.3100 - val_loss: 0.2492 - val_acc: 0.3255
# . theta fit =  [0.8839921 1.418152 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 9s 9us/step - loss: -0.2481 - acc: 0.3259 - val_loss: -0.2494 - val_acc: 0.3255
# . theta fit =  [0.90288395 1.4205126 ]
# Epoch:  17
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2482 - acc: 0.3109 - val_loss: 0.2492 - val_acc: 0.2890
# . theta fit =  [0.90288395 1.4205126 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2483 - acc: 0.2886 - val_loss: -0.2493 - val_acc: 0.2890
# . theta fit =  [0.9089769 1.4250062]
# Epoch:  18
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2482 - acc: 0.3064 - val_loss: 0.2494 - val_acc: 0.2714
# . theta fit =  [0.9089769 1.4250062]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2485 - acc: 0.2709 - val_loss: -0.2494 - val_acc: 0.2714
# . theta fit =  [0.9079716 1.4240528]
# Epoch:  19
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2483 - acc: 0.3040 - val_loss: 0.2493 - val_acc: 0.3248
# . theta fit =  [0.9079716 1.4240528]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2482 - acc: 0.3252 - val_loss: -0.2494 - val_acc: 0.3248
# . theta fit =  [0.9228807 1.4268867]
# Epoch:  20
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2483 - acc: 0.2979 - val_loss: 0.2492 - val_acc: 0.2891
# . theta fit =  [0.9228807 1.4268867]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: -0.2482 - acc: 0.2890 - val_loss: -0.2492 - val_acc: 0.2891
# . theta fit =  [0.9267629 1.4275101]
# Epoch:  21
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2482 - acc: 0.2956 - val_loss: 0.2494 - val_acc: 0.2706
# . theta fit =  [0.9267629 1.4275101]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: -0.2485 - acc: 0.2702 - val_loss: -0.2494 - val_acc: 0.2706
# . theta fit =  [0.9167285 1.4221394]
# Epoch:  22
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2483 - acc: 0.3018 - val_loss: 0.2492 - val_acc: 0.2971
# . theta fit =  [0.9167285 1.4221394]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 10s 10us/step - loss: -0.2481 - acc: 0.2970 - val_loss: -0.2492 - val_acc: 0.2971
# . theta fit =  [0.91952294 1.423217  ]
# Epoch:  23
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2482 - acc: 0.2981 - val_loss: 0.2493 - val_acc: 0.3127
# . theta fit =  [0.91952294 1.423217  ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2482 - acc: 0.3132 - val_loss: -0.2494 - val_acc: 0.3127
# . theta fit =  [0.92965394 1.4255539 ]
# Epoch:  24
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2483 - acc: 0.2941 - val_loss: 0.2492 - val_acc: 0.3013
# . theta fit =  [0.92965394 1.4255539 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2482 - acc: 0.3012 - val_loss: -0.2492 - val_acc: 0.3013
# . theta fit =  [0.9338148 1.4261041]
# Epoch:  25
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: 0.2484 - acc: 0.2958 - val_loss: 0.2493 - val_acc: 0.2776
# . theta fit =  [0.9338148 1.4261041]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2482 - acc: 0.2773 - val_loss: -0.2492 - val_acc: 0.2776
# . theta fit =  [0.9326759 1.425329 ]
# Epoch:  26
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2483 - acc: 0.2926 - val_loss: 0.2492 - val_acc: 0.2885
# . theta fit =  [0.9326759 1.425329 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2481 - acc: 0.2883 - val_loss: -0.2492 - val_acc: 0.2885
# . theta fit =  [0.9337482 1.4245251]
# Epoch:  27
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2483 - acc: 0.2983 - val_loss: 0.2493 - val_acc: 0.3032
# . theta fit =  [0.9337482 1.4245251]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2481 - acc: 0.3031 - val_loss: -0.2493 - val_acc: 0.3032
# . theta fit =  [0.93726164 1.4238938 ]
# Epoch:  28
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2483 - acc: 0.2930 - val_loss: 0.2492 - val_acc: 0.2771
# . theta fit =  [0.93726164 1.4238938 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2482 - acc: 0.2768 - val_loss: -0.2492 - val_acc: 0.2771
# . theta fit =  [0.9360902 1.425395 ]
# Epoch:  29
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2484 - acc: 0.2846 - val_loss: 0.2494 - val_acc: 0.3048
# . theta fit =  [0.9360902 1.425395 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2482 - acc: 0.3049 - val_loss: -0.2495 - val_acc: 0.3048
# . theta fit =  [0.943252  1.4294279]
# Epoch:  30
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2484 - acc: 0.2836 - val_loss: 0.2493 - val_acc: 0.2910
# . theta fit =  [0.943252  1.4294279]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 11s 11us/step - loss: -0.2482 - acc: 0.2908 - val_loss: -0.2493 - val_acc: 0.2910
# . theta fit =  [0.9453274 1.4310387]
# Epoch:  31
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2483 - acc: 0.2819 - val_loss: 0.2500 - val_acc: 0.3186
# . theta fit =  [0.9453274 1.4310387]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2486 - acc: 0.3190 - val_loss: -0.2501 - val_acc: 0.3186
# . theta fit =  [0.95957047 1.4295855 ]
# Epoch:  32
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2485 - acc: 0.2744 - val_loss: 0.2494 - val_acc: 0.2811
# . theta fit =  [0.95957047 1.4295855 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2482 - acc: 0.2811 - val_loss: -0.2494 - val_acc: 0.2811
# . theta fit =  [0.9624093 1.431971 ]
# Epoch:  33
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: 0.2485 - acc: 0.2731 - val_loss: 0.2494 - val_acc: 0.2744
# . theta fit =  [0.9624093 1.431971 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2482 - acc: 0.2743 - val_loss: -0.2493 - val_acc: 0.2744
# . theta fit =  [0.9598242 1.4288923]
# Epoch:  34
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2483 - acc: 0.2739 - val_loss: 0.2493 - val_acc: 0.2873
# . theta fit =  [0.9598242 1.4288923]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2483 - acc: 0.2873 - val_loss: -0.2493 - val_acc: 0.2873
# . theta fit =  [0.9617217 1.4321241]
# Epoch:  35
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2484 - acc: 0.2799 - val_loss: 0.2495 - val_acc: 0.2879
# . theta fit =  [0.9617217 1.4321241]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2483 - acc: 0.2878 - val_loss: -0.2496 - val_acc: 0.2879
# . theta fit =  [0.9683565 1.4374754]
# Epoch:  36
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2483 - acc: 0.2668 - val_loss: 0.2494 - val_acc: 0.2916
# . theta fit =  [0.9683565 1.4374754]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2482 - acc: 0.2917 - val_loss: -0.2494 - val_acc: 0.2916
# . theta fit =  [0.9687258 1.4368691]
# Epoch:  37
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2485 - acc: 0.2632 - val_loss: 0.2494 - val_acc: 0.2901
# . theta fit =  [0.9687258 1.4368691]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2482 - acc: 0.2900 - val_loss: -0.2494 - val_acc: 0.2901
# . theta fit =  [0.970742  1.4389939]
# Epoch:  38
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: 0.2484 - acc: 0.2854 - val_loss: 0.2496 - val_acc: 0.2954
# . theta fit =  [0.970742  1.4389939]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2483 - acc: 0.2960 - val_loss: -0.2496 - val_acc: 0.2954
# . theta fit =  [0.9758112 1.4402218]
# Epoch:  39
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2484 - acc: 0.2728 - val_loss: 0.2494 - val_acc: 0.2710
# . theta fit =  [0.9758112 1.4402218]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 12s 12us/step - loss: -0.2482 - acc: 0.2710 - val_loss: -0.2494 - val_acc: 0.2710
# . theta fit =  [0.9739595 1.4379437]
# Epoch:  40
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2484 - acc: 0.2665 - val_loss: 0.2493 - val_acc: 0.2366
# . theta fit =  [0.9739595 1.4379437]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: -0.2483 - acc: 0.2364 - val_loss: -0.2493 - val_acc: 0.2366
# . theta fit =  [0.9632162 1.4331737]
# Epoch:  41
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2484 - acc: 0.2777 - val_loss: 0.2493 - val_acc: 0.2671
# . theta fit =  [0.9632162 1.4331737]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: -0.2482 - acc: 0.2668 - val_loss: -0.2493 - val_acc: 0.2671
# . theta fit =  [0.95550746 1.4282178 ]
# Epoch:  42
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2484 - acc: 0.2755 - val_loss: 0.2493 - val_acc: 0.2616
# . theta fit =  [0.95550746 1.4282178 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: -0.2483 - acc: 0.2613 - val_loss: -0.2493 - val_acc: 0.2616
# . theta fit =  [0.950637  1.4275478]
# Epoch:  43
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2483 - acc: 0.2796 - val_loss: 0.2493 - val_acc: 0.2580
# . theta fit =  [0.950637  1.4275478]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: -0.2483 - acc: 0.2576 - val_loss: -0.2493 - val_acc: 0.2580
# . theta fit =  [0.9390855 1.4203339]
# Epoch:  44
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2483 - acc: 0.2891 - val_loss: 0.2497 - val_acc: 0.3159
# . theta fit =  [0.9390855 1.4203339]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: -0.2484 - acc: 0.3162 - val_loss: -0.2498 - val_acc: 0.3159
# . theta fit =  [0.95169044 1.4248061 ]
# Epoch:  45
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2483 - acc: 0.2834 - val_loss: 0.2494 - val_acc: 0.2895
# . theta fit =  [0.95169044 1.4248061 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 13s 13us/step - loss: -0.2482 - acc: 0.2894 - val_loss: -0.2494 - val_acc: 0.2895
# . theta fit =  [0.95337725 1.4238857 ]
# Epoch:  46
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2483 - acc: 0.2782 - val_loss: 0.2493 - val_acc: 0.2774
# . theta fit =  [0.95337725 1.4238857 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2773 - val_loss: -0.2493 - val_acc: 0.2774
# . theta fit =  [0.9503893 1.423418 ]
# Epoch:  47
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: 0.2483 - acc: 0.2828 - val_loss: 0.2494 - val_acc: 0.2901
# . theta fit =  [0.9503893 1.423418 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2900 - val_loss: -0.2494 - val_acc: 0.2901
# . theta fit =  [0.9523202 1.4227796]
# Epoch:  48
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2482 - acc: 0.2761 - val_loss: 0.2493 - val_acc: 0.2602
# . theta fit =  [0.9523202 1.4227796]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2600 - val_loss: -0.2492 - val_acc: 0.2602
# . theta fit =  [0.94231606 1.4193869 ]
# Epoch:  49
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2483 - acc: 0.2864 - val_loss: 0.2493 - val_acc: 0.2862
# . theta fit =  [0.94231606 1.4193869 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2481 - acc: 0.2860 - val_loss: -0.2493 - val_acc: 0.2862
# . theta fit =  [0.94566864 1.4234937 ]
# Epoch:  50
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2483 - acc: 0.2905 - val_loss: 0.2494 - val_acc: 0.2930
# . theta fit =  [0.94566864 1.4234937 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2930 - val_loss: -0.2495 - val_acc: 0.2930
# . theta fit =  [0.9509029 1.4273297]
# Epoch:  51
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2483 - acc: 0.2893 - val_loss: 0.2494 - val_acc: 0.2809
# . theta fit =  [0.9509029 1.4273297]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2805 - val_loss: -0.2494 - val_acc: 0.2809
# . theta fit =  [0.9486989 1.427827 ]
# Epoch:  52
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2484 - acc: 0.2833 - val_loss: 0.2493 - val_acc: 0.2753
# . theta fit =  [0.9486989 1.427827 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2751 - val_loss: -0.2493 - val_acc: 0.2753
# . theta fit =  [0.95042217 1.4309019 ]
# Epoch:  53
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2483 - acc: 0.2866 - val_loss: 0.2494 - val_acc: 0.2923
# . theta fit =  [0.95042217 1.4309019 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2921 - val_loss: -0.2495 - val_acc: 0.2923
# . theta fit =  [0.95772153 1.4369446 ]
# Epoch:  54
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: 0.2484 - acc: 0.2779 - val_loss: 0.2494 - val_acc: 0.2828
# . theta fit =  [0.95772153 1.4369446 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2482 - acc: 0.2826 - val_loss: -0.2493 - val_acc: 0.2828
# . theta fit =  [0.94874406 1.4238224 ]
# Epoch:  55
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2484 - acc: 0.2876 - val_loss: 0.2494 - val_acc: 0.2853
# . theta fit =  [0.94874406 1.4238224 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 14s 14us/step - loss: -0.2482 - acc: 0.2852 - val_loss: -0.2495 - val_acc: 0.2853
# . theta fit =  [0.9520496 1.4284519]
# Epoch:  56
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2484 - acc: 0.2729 - val_loss: 0.2493 - val_acc: 0.2912
# . theta fit =  [0.9520496 1.4284519]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2482 - acc: 0.2910 - val_loss: -0.2493 - val_acc: 0.2912
# . theta fit =  [0.95362836 1.4319987 ]
# Epoch:  57
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2484 - acc: 0.2897 - val_loss: 0.2496 - val_acc: 0.3000
# . theta fit =  [0.95362836 1.4319987 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2483 - acc: 0.3004 - val_loss: -0.2496 - val_acc: 0.3000
# . theta fit =  [0.9617925 1.4345587]
# Epoch:  58
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2484 - acc: 0.2805 - val_loss: 0.2496 - val_acc: 0.2993
# . theta fit =  [0.9617925 1.4345587]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2483 - acc: 0.2998 - val_loss: -0.2496 - val_acc: 0.2993
# . theta fit =  [0.9646796 1.4314836]
# Epoch:  59
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2484 - acc: 0.2767 - val_loss: 0.2495 - val_acc: 0.2876
# . theta fit =  [0.9646796 1.4314836]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2482 - acc: 0.2876 - val_loss: -0.2495 - val_acc: 0.2876
# . theta fit =  [0.96356153 1.4308733 ]
# Epoch:  60
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: 0.2484 - acc: 0.2732 - val_loss: 0.2494 - val_acc: 0.2848
# . theta fit =  [0.96356153 1.4308733 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2482 - acc: 0.2848 - val_loss: -0.2495 - val_acc: 0.2848
# . theta fit =  [0.96488667 1.4352932 ]
# Epoch:  61
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2484 - acc: 0.2749 - val_loss: 0.2495 - val_acc: 0.2905
# . theta fit =  [0.96488667 1.4352932 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2482 - acc: 0.2905 - val_loss: -0.2495 - val_acc: 0.2905
# . theta fit =  [0.96787316 1.4365678 ]
# Epoch:  62
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2486 - acc: 0.2719 - val_loss: 0.2494 - val_acc: 0.2618
# . theta fit =  [0.96787316 1.4365678 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 15s 15us/step - loss: -0.2482 - acc: 0.2614 - val_loss: -0.2494 - val_acc: 0.2618
# . theta fit =  [0.96234566 1.4316862 ]
# Epoch:  63
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2484 - acc: 0.2695 - val_loss: 0.2493 - val_acc: 0.2680
# . theta fit =  [0.96234566 1.4316862 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2483 - acc: 0.2680 - val_loss: -0.2493 - val_acc: 0.2680
# . theta fit =  [0.95701855 1.4293534 ]
# Epoch:  64
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2484 - acc: 0.2833 - val_loss: 0.2495 - val_acc: 0.2961
# . theta fit =  [0.95701855 1.4293534 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2482 - acc: 0.2962 - val_loss: -0.2495 - val_acc: 0.2961
# . theta fit =  [0.95800745 1.4261383 ]
# Epoch:  65
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2484 - acc: 0.2761 - val_loss: 0.2495 - val_acc: 0.2951
# . theta fit =  [0.95800745 1.4261383 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2482 - acc: 0.2950 - val_loss: -0.2495 - val_acc: 0.2951
# . theta fit =  [0.95888877 1.420777  ]
# Epoch:  66
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2483 - acc: 0.2808 - val_loss: 0.2495 - val_acc: 0.2889
# . theta fit =  [0.95888877 1.420777  ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2482 - acc: 0.2889 - val_loss: -0.2495 - val_acc: 0.2889
# . theta fit =  [0.9608805 1.4215767]
# Epoch:  67
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 18s 18us/step - loss: 0.2483 - acc: 0.2768 - val_loss: 0.2493 - val_acc: 0.2840
# . theta fit =  [0.9608805 1.4215767]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2481 - acc: 0.2840 - val_loss: -0.2493 - val_acc: 0.2840
# . theta fit =  [0.95391613 1.416635  ]
# Epoch:  68
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2482 - acc: 0.2781 - val_loss: 0.2493 - val_acc: 0.2819
# . theta fit =  [0.95391613 1.416635  ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 16s 16us/step - loss: -0.2481 - acc: 0.2817 - val_loss: -0.2493 - val_acc: 0.2819
# . theta fit =  [0.9549457 1.4183489]
# Epoch:  69
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: 0.2484 - acc: 0.2751 - val_loss: 0.2493 - val_acc: 0.2878
# . theta fit =  [0.9549457 1.4183489]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: -0.2482 - acc: 0.2876 - val_loss: -0.2493 - val_acc: 0.2878
# . theta fit =  [0.9591599 1.4224551]
# Epoch:  70
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 18s 18us/step - loss: 0.2484 - acc: 0.2760 - val_loss: 0.2494 - val_acc: 0.2881
# . theta fit =  [0.9591599 1.4224551]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: -0.2482 - acc: 0.2880 - val_loss: -0.2494 - val_acc: 0.2881
# . theta fit =  [0.9582559 1.4195044]
# Epoch:  71
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 18s 18us/step - loss: 0.2484 - acc: 0.2718 - val_loss: 0.2493 - val_acc: 0.2894
# . theta fit =  [0.9582559 1.4195044]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: -0.2482 - acc: 0.2894 - val_loss: -0.2494 - val_acc: 0.2894
# . theta fit =  [0.96005625 1.4205664 ]
# Epoch:  72
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 18s 18us/step - loss: 0.2484 - acc: 0.2780 - val_loss: 0.2494 - val_acc: 0.2889
# . theta fit =  [0.96005625 1.4205664 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: -0.2482 - acc: 0.2889 - val_loss: -0.2494 - val_acc: 0.2889
# . theta fit =  [0.95567364 1.4174961 ]
# Epoch:  73
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 18s 18us/step - loss: 0.2484 - acc: 0.2787 - val_loss: 0.2493 - val_acc: 0.2839
# . theta fit =  [0.95567364 1.4174961 ]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: -0.2482 - acc: 0.2838 - val_loss: -0.2493 - val_acc: 0.2839
# . theta fit =  [0.9575448 1.4201572]
# Epoch:  74
# Training g
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 19s 19us/step - loss: 0.2483 - acc: 0.2763 - val_loss: 0.2493 - val_acc: 0.2698
# . theta fit =  [0.9575448 1.4201572]
# Training theta
# Train on 1000000 samples, validate on 1000000 samples
# Epoch 1/1
# 1000000/1000000 [==============================] - 17s 17us/step - loss: -0.2482 - acc: 0.2695 - val_loss: -0.2493 - val_acc: 0.2698
# . theta fit =  [0.95225424 1.4188765 ]

# %%
fit_vals = np.array(fit_vals)

plt.plot(fit_vals[:,0], label='Model $\mu$ Fit')
plt.plot(fit_vals[:,1], label='Model $\sigma$ Fit')
plt.hlines(theta1_param[0], 0, len(fit_vals), label = '$\mu_{Truth}$')
plt.hlines(theta1_param[1], 0, len(fit_vals), label = '$\sigma_{Truth}$')
plt.xlabel("Epochs")
plt.ylabel(r'$\theta_{fit}$')
plt.legend()
plt.title("GaussianAltFit-2D-Detector Effects ANALYTICAL REWEIGHT:\n N = {:.0e}, learning rate = {:.0e}, Epochs = {:.0f}".format(N, lr, len(fit_vals)))
#plt.savefig("GaussianAltFit-2D-Detector Effects ANALYTICAL REWEIGHT: = {:.0e}, learning rate = {:.0e}, Epochs = {:.0f}.png".format(N, lr, len(fit_vals)))
plt.show()

# %%
correct_weights = np.array([[theta1_param[0], theta1_param[1]]])

model_fit.layers[-1].set_weights(correct_weights)
print(model_fit.evaluate(x=X_train, y=y_test, batch_size = 1000))
print("^", model_fit.metrics_names)
# Out:
# 1000000/1000000 [==============================] - 3s 3us/step
# [-0.25021931307017803, 0.2500920003354549]
# ^ ['loss', 'acc']
